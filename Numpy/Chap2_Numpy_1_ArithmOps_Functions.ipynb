# %% [markdown]
# ## <span style="font-family: Arial; color:Crimson; font-style:bold"> Arithmetic operations on  Numpy arrays and Numpy Functions  </span>
#
# 1. Numpy array creation using Random Number Generation
#
#     **Review**:
#     - create a numpy array by using `numpy.array()`
#     - create a numpy array by using `numpy.arange()` + `numpy.reshape()`
#     - create a numpy array by using special functions, e.g., `numpy.zeros()`, `numpy.ones()`, `numpy.eye()`, `numpy.fill()`
#
# 2. Basic Arithmetic Operations
#
# 3. Special Numpy Functions for Arithmetic
# - Applications in Image Processing
#
# 4. Aggregation & Statistical Functions

# %%
import numpy as np

# %% [markdown]
# ### <span style = "color: maroon"> 1. Numpy array creation using Random Number Generation </span>
#
# NumPy provides a module numpy.random for generating random numbers.
#
# | **Function** | **Description** |
# |-------------|----------------|
# | `np.random.rand(n)` | Generates an array of random floats between 0 and 1 |
# | `np.random.randint(low, high, size)` | Generates random integers in a given range |

# %%
random_array = np.random.randint(0,10, (3,3))  # 3x3 matrix with random values between 0 and 10
print(random_array )
# Out:
# [[0 6 0]
#  [8 2 5]
#  [4 5 9]]

# %%
random_array = np.random.rand(3,3)  # 3x3 matrix with random values between 0 and 1
print(random_array.round(2))#小数点后数字位数，小数点后两位
# Out:
# [[0.26 0.06 0.42]
#  [0.65 0.02 0.86]
#  [0.27 0.47 0.23]]

# %%
range_array=np.random.randint(15,25,(3,4)) # 3x4 matrix with random values between 15 and 25
range_array.round(3)#小数点后数字位数，小数点后3位，但因为是int所以无改变
# Out:
# array([[19, 24, 15, 17],
#        [16, 23, 17, 21],
#        [22, 17, 24, 23]])

# %% [markdown]
# ### <span style = "color: maroon"> 2. Basic Arithmetic Operations (Element-wise arithmetic operations) </span>
#
# NumPy supports addition (+), subtraction (-), multiplication (*), division (/), exponentiation (), and modulus (%)**.

# %%
# Creating NumPy arrays
a = np.array([1, 2, 3, 4])
b = np.array([5, 6, 7, 8])

# Element-wise operations
print(f'a + b = {a + b}')   # Addition
print(f'a - b = {a - b}')   # Subtraction
print(f'a * b = {a * b}')   # Multiplication
print(f'a/b={a/b}')
print(f'a / b = {np.round(a / b, 2)}')   # Division
print(f'a ** 2 = {a ** 2}')  # Exponentiation (Square of each element)
print(f'a % 2 = {a % 2}')   # Modulus (Remainder)
# Out:
# a + b = [ 6  8 10 12]
# a - b = [-4 -4 -4 -4]
# a * b = [ 5 12 21 32]
# a/b=[0.2        0.33333333 0.42857143 0.5       ]
# a / b = [0.2  0.33 0.43 0.5 ]
# a ** 2 = [ 1  4  9 16]
# a % 2 = [1 0 1 0]

# %% [markdown]
# ### <span style = "color: maroon"> 3. Special Numpy Functions for Arithmetic </span>
#  NumPy provides optimized functions for element-wise operations.
#  | **Operation**   | **Function**               |
# |---------------|--------------------------|
# | Addition      | `np.add(a, b)`           |
# | Subtraction   | `np.subtract(a, b)`      |
# | Multiplication| `np.multiply(a, b)`      |
# | Division      | `np.divide(a, b)`        |
# | Power        | `np.power(a, b)`         |
# | Modulus       | `np.mod(a, b)`           |
# | Round       | `np.round(number, numOfDigits)`           |

# %%
print(np.add(a, b))  # Same as a + b
print(np.multiply(a, 2))  # Same as a * 2
# Out:
# [ 6  8 10 12]
# [2 4 6 8]

# %% [markdown]
# ### <span style = "color: orangered">  Practice 1 </span>
# 1. Create a 2 x 4 Numpy array `arr_random` with random values in [10, 20)
#
# 2. Subtract 10 from each element of the array
#
# 3. Show `arr_random` to verify the results

# %%
arr_random=np.random.randint(10,20,(2,4))
print(arr_random)
substract_arr_random=np.subtract(arr_random,10)
print(substract_arr_random)
# Out:
# [[16 16 18 19]
#  [13 19 12 17]]
# [[6 6 8 9]
#  [3 9 2 7]]

# %% [markdown]
# ### <span style = "color: maroon"> 🔥 Applications in Image Processing </span>
# 1\) Generate a negative image by substracting each pixel's RGB values from 255.
#
# 2\) Contrast adjustment by scaling pixel values
#
# 3\) Brightness adjustment by adding a positive value to pixels

# %%
# importing all the required libraries
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image, ImageOps

#source: https://www.analyticsvidhya.com/blog/2021/05/image-processing-using-numpy-with-practical-implementation-and-code/?

# %%
img = np.array(Image.open('EmmaStone.jpg'))
plt.figure(figsize=(5,5))
plt.imshow(img)

# %%
print('# of dims: ',img.ndim)     # dimension of an image
print('Img shape: ',img.shape)    # shape of an image
print('Dtype: ',img.dtype)
# Out:
# # of dims:  3
# Img shape:  (587, 798, 3)
# Dtype:  uint8

# %% [markdown]
# ### 1 \) **Negative of an Image**
# Converting a color image to a negative image is very simple. You to perform only 3 steps for each pixel of the image
#
# - First, get the RGB values of the pixel
#
# - Calculate new RGB values using R = 255 – R, G = 255 – G, B = 255- B
#
# - Finally, save the new RGB values in the pixel

# %%
fig = plt.figure(figsize=(10, 10))

fig.add_subplot(1, 2, 1) 
#图形窗口被分成 1 行 2 列的子区域，1 表示选择第一个位置。
#Show original image                
plt.imshow(img) #Display the image
plt.title('Original image')

#show negative imge
img_negative = 255 - img #形成负片

fig.add_subplot(1, 2, 2)
plt.imshow(img_negative)
plt.title('Negative of RGB image')
# Out:
# Text(0.5, 1.0, 'Negative of RGB image')

# %% [markdown]
# ### 2 \) **Contrast Adjustment**
# - We enhance contrast by multiplying pixel values by a scaling factor.
# - If img is the original image stored as a NumPy array, we scale it using:
#
#         new_img = img ∗ factor
#
# - The factor should be greater than 1 to increase contrast and less than 1 to reduce contrast.
# - We clip values to ensure they remain within the valid pixel range [0, 255].

# %%
fig = plt.figure(figsize=(10, 10))

fig.add_subplot(1, 2, 1)
#Show original image                
plt.imshow(img)
plt.title('Original image')

# Apply contrast enhancement (increase contrast)
contrast_factor = 2.5  # Increase contrast by 2.5x 
                        #Note: >1 increases contrast, <1 decreases contrast
img_contrast = np.clip(img * contrast_factor, 0, 255).astype(np.uint8)

#clip 函数将图像的像素值限制在 0 到 255 之间，因为图像的像素值不能超出这个范围。
#若某个像素值小于 0，会被设为 0；若大于 255，会被设为 255。

#.astype(np.uint8)：将像素值转换为 8 位无符号整数类型，
#因为图像的像素值通常是 uint8 类型（0 到 255 之间）。

fig.add_subplot(1, 2, 2)
plt.imshow(img_contrast)
plt.title('Contrast Enhanced Image')
# Out:
# Text(0.5, 1.0, 'Contrast Enhanced Image')

# %% [markdown]
# ### 3 \) **Brightness Adjustment**
# - Brightness adjustment formula
#
#         new_img = img + brightness_factor
# - Adding a positive value increases brightness.
# - Adding a negative value decreases brightness.
# - We clip the values to [0, 255] to avoid invalid pixel values.

# %%
fig = plt.figure(figsize=(10, 10))

fig.add_subplot(1, 2, 1)
#Show original image                
plt.imshow(img)
plt.title('Original image')

# Convert image to float before modifying brightness
img_float = img.astype(np.float32)  # Prevents overflow, since img.dtype is uint8.
#将原始图像 img 从 uint8 数据类型转换为 float32。
#这样做是为了避免在增加亮度时发生溢出，
#因为 uint8 数据类型的像素值范围是 0 到 255，而 float32 可以表示更大的数值。

# Increase brightness
brightness_factor = 100  # Increase brightness by adding 50 to each pixel
 
img_bright = np.clip(img_float + brightness_factor, 0, 255).astype(np.uint8)


# Show brightened image
fig.add_subplot(1, 2, 2)
plt.imshow(img_bright)
plt.title('Brightened Image')

plt.show()

# %% [markdown]
# ### **Numpy.astype()**
#
# The .astype() method in NumPy is used to convert the data type (dtype) of an array to a different type.
#
# Syntax:
#
#         `array.astype(new_dtype)`
#
#
# - array : The NumPy array to be converted.
# - new_dtype : The target data type (np.int32, np.float64, np.uint8, etc.).

# %%
arr = np.array([1.9, 2.5, 3.8, 4.2])
arr_int = arr.astype(np.int32)

print(arr_int)       # Output: [1 2 3 4] truncates the decimal part
print(arr_int.dtype) # Output: int32
# Out:
# [1 2 3 4]
# int32

# %%
# Recall the type casting example that we saw earlier. Let's convert a string to a float number using the float() function.
str_number = '1234.56'
number = float(str_number)
print(number)  # Output: 1234.56
# Out:
# 1234.56

# %% [markdown]
# ### <span style = "color: orangered">  Practice 2 </span>
# Given the following string array,
# ```python
#     arr_str = np.array(['1', '2', '3', '4'])
# ```
# convert it to an int array [1, 2, 3, 4]

# %%
arr_str = np.array(['1', '2', '3', '4'])

# %% [markdown]
# ### <span style = "color: maroon"> 4. Aggregation & Statistical Functions </span>
#
# Numpy also provides functions performing summarization across an array, such as computing sums, means, or standard deviations.
#
# | **Function**     | **Description** |
# |-----------------|----------------|
# | `np.sum(a)`     | Computes the sum of all elements in `a` |
# | `np.mean(a)`    | Computes the mean (average) of `a` |
# | `np.median(a)`  | Computes the median of `a` |
# | `np.std(a)`     | Computes the standard deviation |
# | `np.var(a)`     | Computes the variance |
# | `np.min(a)`     | Returns the minimum value |
# | `np.max(a)`     | Returns the maximum value |

# %%
arr2 = np.array([[4, 2, 3],
                [1, 5, 6]])
print(arr2)
# Out:
# [[4 2 3]
#  [1 5 6]]

# %%
print(np.sum(arr2))   
print(np.mean(arr2))  
print(np.min(arr2))   
print(np.max(arr2))
# Out:
# 21
# 3.5
# 1
# 6

# %%
print(arr2)
#sum up all elements in the ndarray
arr2.sum(axis = 0) #sum up all elements in the columns
# Out:
# [[4 2 3]
#  [1 5 6]]
# array([5, 7, 9])

# %%
print(arr2)
#sum up all elements in the ndarray
arr2.sum(axis = 1) #sum up all elements in the columns
# Out:
# [[4 2 3]
#  [1 5 6]]
# array([ 9, 12])

# %% [markdown]
# ### <span style = "color: orangered">  Practice 3 </span>
#
# Given the above `arr2`, Calculate and show a list containing the maximum value of each column.

# %%
print(arr2)
# Out:
# [[4 2 3]
#  [1 5 6]]
